# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\ameet\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\ameet\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\ameet\anaconda3\lib\site-packages (from spotipy) (4.5.4)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ameet\anaconda3\lib\site-packages (from spotipy) (1.26.11)
# Requirement already satisfied: six>=1.15.0 in c:\users\ameet\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\ameet\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ameet\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ameet\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ameet\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.9.14)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="") #removed for security purpose

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1n9EM0Y4A89vuRiA93gSS9'},
#       'href': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9',
#       'id': '1n9EM0Y4A89vuRiA93gSS9',
#       'name': 'Kaifi Khalil',
#       'type': 'artist',
#       'uri': 'spotify:artist:1n9EM0Y4A89vuRiA93gSS9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'},
#     'href': 'https://api.spotify.com/v1/albums/6BHlJhCk1vjCG6hqTG2SFV',
#     'id': '6BHlJhCk1vjCG6hqTG2SFV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734697d4ee22b3f63c17a3b9ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024697d4ee22b3f63c17a3b9ec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514697d4ee22b3f63c17a3b9ec',
#       'width': 64}],
#     'name': 'Kahani Suno 2.0',
#     'release_date': '2022-05-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6BHlJhCk1vjCG6hqTG2SFV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1n9EM0Y4A89vuRiA93gSS9'},
#      'href': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9',
#      'id': '1n9EM0Y4A89vuRiA93gSS9',
#      'name': 'Kaifi Khalil',
#      'type': 'artist',
#      'uri': 'spotify:artist:1n9EM0Y4A89vuRiA93gSS9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 173637,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZK6Q2278612'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4VsP4Dm8gsibRxB5I2hEkw'},
#    'href': 'https://api.spotify.com/v1/tracks/4VsP4Dm8gsibRxB5I2hEkw',
#    'id': '4VsP4Dm8gsibRxB5I2hEkw',
#    'is_local': False,
#    'name': 'Kahani Suno 2.0',
#    'popularity': 85,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2c644e9345d1a0ab97e4541d26b6b8ccb2c889f9?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4VsP4Dm8gsibRxB5I2hEkw'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#       'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#       'id': '1wRPtKGflJrBx9BmLsSwlU',
#       'name': 'Pritam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#       'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#       'id': '2fMqTqiTxUDlmcOEPaQSsx',
#       'name': 'Amitabh Bhattacharya',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7kXEDaT5yy8IUT7Fmqs1i2'},
#     'href': 'https://api.spotify.com/v1/albums/7kXEDaT5yy8IUT7Fmqs1i2',
#     'id': '7kXEDaT5yy8IUT7Fmqs1i2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a733a9eeabca1a5fb50312b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a733a9eeabca1a5fb50312b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a733a9eeabca1a5fb50312b',
#       'width': 64}],
#     'name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#     'release_date': '2023-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7kXEDaT5yy8IUT7Fmqs1i2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#      'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#      'id': '1wRPtKGflJrBx9BmLsSwlU',
#      'name': 'Pritam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#      'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#      'id': '2fMqTqiTxUDlmcOEPaQSsx',
#      'name': 'Amitabh Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 313051,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182300550'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0czcoKJbJt08NqKrvSbbz7'},
#    'href': 'https://api.spotify.com/v1/tracks/0czcoKJbJt08NqKrvSbbz7',
#    'id': '0czcoKJbJt08NqKrvSbbz7',
#    'is_local': False,
#    'name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/63f3c9be6a7b68ba1ec33baa701140d6b4837aca?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0czcoKJbJt08NqKrvSbbz7'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#       'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#       'id': '5NHm4TU5Twz7owibYxJfFU',
#       'name': 'King',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'},
#     'href': 'https://api.spotify.com/v1/albums/15CyNDuGY5fsG0Hn9rjnpG',
#     'id': '15CyNDuGY5fsG0Hn9rjnpG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27337f65266754703fd20d29854',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0237f65266754703fd20d29854',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485137f65266754703fd20d29854',
#       'width': 64}],
#     'name': 'Champagne Talk',
#     'release_date': '2022-10-12',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:15CyNDuGY5fsG0Hn9rjnpG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#      'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#      'id': '5NHm4TU5Twz7owibYxJfFU',
#      'name': 'King',
#      'type': 'artist',
#      'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 194653,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INW272200083'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1418IuVKQPTYqt7QNJ9RXN'},
#    'href': 'https://api.spotify.com/v1/tracks/1418IuVKQPTYqt7QNJ9RXN',
#    'id': '1418IuVKQPTYqt7QNJ9RXN',
#    'is_local': False,
#    'name': 'Maan Meri Jaan',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cf886ec5f6a46c234bcfdd043ab5db03db0015b4?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1418IuVKQPTYqt7QNJ9RXN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#       'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#       'id': '1wRPtKGflJrBx9BmLsSwlU',
#       'name': 'Pritam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#       'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#       'id': '2fMqTqiTxUDlmcOEPaQSsx',
#       'name': 'Amitabh Bhattacharya',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'},
#     'href': 'https://api.spotify.com/v1/albums/4kIPlpwEZBK9JaI9pZHe79',
#     'id': '4kIPlpwEZBK9JaI9pZHe79',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273913edcaccb2268647d0c495b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02913edcaccb2268647d0c495b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851913edcaccb2268647d0c495b',
#       'width': 64}],
#     'name': 'Brahmastra (Original Motion Picture Soundtrack)',
#     'release_date': '2022-10-06',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:4kIPlpwEZBK9JaI9pZHe79'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#      'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#      'id': '1wRPtKGflJrBx9BmLsSwlU',
#      'name': 'Pritam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#      'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#      'id': '2fMqTqiTxUDlmcOEPaQSsx',
#      'name': 'Amitabh Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 268164,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS172203702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4UMIv5jd9gK98a39BQRD9X'},
#    'href': 'https://api.spotify.com/v1/tracks/4UMIv5jd9gK98a39BQRD9X',
#    'id': '4UMIv5jd9gK98a39BQRD9X',
#    'is_local': False,
#    'name': 'Kesariya',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/767976462df41e836ac0d5bccfd528376c92d2ba?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4UMIv5jd9gK98a39BQRD9X'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#       'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#       'id': '1E6arsXf5Fgsnv9YpSzjpE',
#       'name': 'Parampara Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0m3D4grap8VFSzbJMqgNVk'},
#       'href': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk',
#       'id': '0m3D4grap8VFSzbJMqgNVk',
#       'name': 'Kumaar',
#       'type': 'artist',
#       'uri': 'spotify:artist:0m3D4grap8VFSzbJMqgNVk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7khRLZe8P6XcUoRgOa3nnf'},
#     'href': 'https://api.spotify.com/v1/albums/7khRLZe8P6XcUoRgOa3nnf',
#     'id': '7khRLZe8P6XcUoRgOa3nnf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e4be675de3a03b2ad2552c6d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e4be675de3a03b2ad2552c6d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e4be675de3a03b2ad2552c6d',
#       'width': 64}],
#     'name': 'Malang Sajna',
#     'release_date': '2022-12-19',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7khRLZe8P6XcUoRgOa3nnf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#      'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#      'id': '6WOdPJmexxFINcKMkP2jMG',
#      'name': 'Sachet Tandon',
#      'type': 'artist',
#      'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#      'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#      'id': '1E6arsXf5Fgsnv9YpSzjpE',
#      'name': 'Parampara Tandon',
#      'type': 'artist',
#      'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0m3D4grap8VFSzbJMqgNVk'},
#      'href': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk',
#      'id': '0m3D4grap8VFSzbJMqgNVk',
#      'name': 'Kumaar',
#      'type': 'artist',
#      'uri': 'spotify:artist:0m3D4grap8VFSzbJMqgNVk'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 161041,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182203702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73K33p4Vyz9koXGqmL5eFs'},
#    'href': 'https://api.spotify.com/v1/tracks/73K33p4Vyz9koXGqmL5eFs',
#    'id': '73K33p4Vyz9koXGqmL5eFs',
#    'is_local': False,
#    'name': 'Malang Sajna',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/adc1a73cffab5e6edea79f5a481257068f929f46?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:73K33p4Vyz9koXGqmL5eFs'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#       'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#       'id': '1wRPtKGflJrBx9BmLsSwlU',
#       'name': 'Pritam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#       'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#       'id': '2fMqTqiTxUDlmcOEPaQSsx',
#       'name': 'Amitabh Bhattacharya',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5uAi4ZZc7zRdd6PsKNcJXO'},
#     'href': 'https://api.spotify.com/v1/albums/5uAi4ZZc7zRdd6PsKNcJXO',
#     'id': '5uAi4ZZc7zRdd6PsKNcJXO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fdd4cc7defb987b4c3aa2d9e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fdd4cc7defb987b4c3aa2d9e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fdd4cc7defb987b4c3aa2d9e',
#       'width': 64}],
#     'name': 'Tere Pyaar Mein (From "Tu Jhoothi Main Makkaar")',
#     'release_date': '2023-02-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5uAi4ZZc7zRdd6PsKNcJXO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wRPtKGflJrBx9BmLsSwlU'},
#      'href': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU',
#      'id': '1wRPtKGflJrBx9BmLsSwlU',
#      'name': 'Pritam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wRPtKGflJrBx9BmLsSwlU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#      'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#      'id': '4YRxDV8wJFPHPTeXepOstw',
#      'name': 'Arijit Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx'},
#      'href': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx',
#      'id': '2fMqTqiTxUDlmcOEPaQSsx',
#      'name': 'Amitabh Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:2fMqTqiTxUDlmcOEPaQSsx'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tPQOjkxO3mrYrrgkTeXgH'},
#      'href': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH',
#      'id': '3tPQOjkxO3mrYrrgkTeXgH',
#      'name': 'Nikhita Gandhi',
#      'type': 'artist',
#      'uri': 'spotify:artist:3tPQOjkxO3mrYrrgkTeXgH'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 266094,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182300213'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ZD4aIEepqZsdxPxLSuUhm'},
#    'href': 'https://api.spotify.com/v1/tracks/2ZD4aIEepqZsdxPxLSuUhm',
#    'id': '2ZD4aIEepqZsdxPxLSuUhm',
#    'is_local': False,
#    'name': 'Tere Pyaar Mein',
#    'popularity': 83,
#    'preview_url': 'https://p.scdn.co/mp3-preview/934085d1005df2d8d0e94833795f9a155dd77d64?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2ZD4aIEepqZsdxPxLSuUhm'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfi47LWmlXzQ3p3kWonfQ'},
#       'href': 'https://api.spotify.com/v1/artists/2kfi47LWmlXzQ3p3kWonfQ',
#       'id': '2kfi47LWmlXzQ3p3kWonfQ',
#       'name': 'Madhur Sharma',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kfi47LWmlXzQ3p3kWonfQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/16023OFrIxSmKOMpIVJ6Ax'},
#       'href': 'https://api.spotify.com/v1/artists/16023OFrIxSmKOMpIVJ6Ax',
#       'id': '16023OFrIxSmKOMpIVJ6Ax',
#       'name': 'Swapnil Tare',
#       'type': 'artist',
#       'uri': 'spotify:artist:16023OFrIxSmKOMpIVJ6Ax'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5HcunTidTUrOaf8V0iJcvl'},
#       'href': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl',
#       'id': '5HcunTidTUrOaf8V0iJcvl',
#       'name': 'Nusrat Fateh Ali Khan',
#       'type': 'artist',
#       'uri': 'spotify:artist:5HcunTidTUrOaf8V0iJcvl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1zLlgNA1tyiabDhDwWhyPG'},
#     'href': 'https://api.spotify.com/v1/albums/1zLlgNA1tyiabDhDwWhyPG',
#     'id': '1zLlgNA1tyiabDhDwWhyPG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27320e50799751550f6f23ade5a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0220e50799751550f6f23ade5a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485120e50799751550f6f23ade5a',
#       'width': 64}],
#     'name': 'Kali Kali Zulfon Ke (Lo-Fi)',
#     'release_date': '2023-03-31',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1zLlgNA1tyiabDhDwWhyPG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfi47LWmlXzQ3p3kWonfQ'},
#      'href': 'https://api.spotify.com/v1/artists/2kfi47LWmlXzQ3p3kWonfQ',
#      'id': '2kfi47LWmlXzQ3p3kWonfQ',
#      'name': 'Madhur Sharma',
#      'type': 'artist',
#      'uri': 'spotify:artist:2kfi47LWmlXzQ3p3kWonfQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/16023OFrIxSmKOMpIVJ6Ax'},
#      'href': 'https://api.spotify.com/v1/artists/16023OFrIxSmKOMpIVJ6Ax',
#      'id': '16023OFrIxSmKOMpIVJ6Ax',
#      'name': 'Swapnil Tare',
#      'type': 'artist',
# ...
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'FM',
#     'NA',
#     'NE',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 217746,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC11502934'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2J2Z1SkXYghSajLibnQHOa'},
#    'href': 'https://api.spotify.com/v1/tracks/2J2Z1SkXYghSajLibnQHOa',
#    'id': '2J2Z1SkXYghSajLibnQHOa',
#    'is_local': False,
#    'name': 'Unstoppable',
#    'popularity': 83,
#    'preview_url': 'https://p.scdn.co/mp3-preview/99a07d00531c0053f55a46e94ed92b1560396754?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2J2Z1SkXYghSajLibnQHOa'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zZrFenNe3YPttxZsnQQs1'},
#       'href': 'https://api.spotify.com/v1/artists/6zZrFenNe3YPttxZsnQQs1',
#       'id': '6zZrFenNe3YPttxZsnQQs1',
#       'name': 'Akhil',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zZrFenNe3YPttxZsnQQs1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1OPqAyxsQc8mcRmoNBAnVk'},
#       'href': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk',
#       'id': '1OPqAyxsQc8mcRmoNBAnVk',
#       'name': 'Dhvani Bhanushali',
#       'type': 'artist',
#       'uri': 'spotify:artist:1OPqAyxsQc8mcRmoNBAnVk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/52XgeWw24o4klNdfwvB0Vx'},
#       'href': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx',
#       'id': '52XgeWw24o4klNdfwvB0Vx',
#       'name': 'Kunaal Vermaa',
#       'type': 'artist',
#       'uri': 'spotify:artist:52XgeWw24o4klNdfwvB0Vx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hzAIEMlQpsEGIQFvnFOQx'},
#     'href': 'https://api.spotify.com/v1/albums/5hzAIEMlQpsEGIQFvnFOQx',
#     'id': '5hzAIEMlQpsEGIQFvnFOQx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737b93fd8b0ade33ceb9d536de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027b93fd8b0ade33ceb9d536de',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517b93fd8b0ade33ceb9d536de',
#       'width': 64}],
#     'name': 'Duniyaa (From "Luka Chuppi")',
#     'release_date': '2019-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5hzAIEMlQpsEGIQFvnFOQx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zZrFenNe3YPttxZsnQQs1'},
#      'href': 'https://api.spotify.com/v1/artists/6zZrFenNe3YPttxZsnQQs1',
#      'id': '6zZrFenNe3YPttxZsnQQs1',
#      'name': 'Akhil',
#      'type': 'artist',
#      'uri': 'spotify:artist:6zZrFenNe3YPttxZsnQQs1'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1OPqAyxsQc8mcRmoNBAnVk'},
#      'href': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk',
#      'id': '1OPqAyxsQc8mcRmoNBAnVk',
#      'name': 'Dhvani Bhanushali',
#      'type': 'artist',
#      'uri': 'spotify:artist:1OPqAyxsQc8mcRmoNBAnVk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/52XgeWw24o4klNdfwvB0Vx'},
#      'href': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx',
#      'id': '52XgeWw24o4klNdfwvB0Vx',
#      'name': 'Kunaal Vermaa',
#      'type': 'artist',
#      'uri': 'spotify:artist:52XgeWw24o4klNdfwvB0Vx'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 222500,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS181900390'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2tjWCe2W7sgvS3C8NHcdtI'},
#    'href': 'https://api.spotify.com/v1/tracks/2tjWCe2W7sgvS3C8NHcdtI',
#    'id': '2tjWCe2W7sgvS3C8NHcdtI',
#    'is_local': False,
#    'name': 'Duniyaa (From "Luka Chuppi")',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/615d8699b9be2363bd0ad31a19a43846c63bd99f?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2tjWCe2W7sgvS3C8NHcdtI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-04-28T13:10:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wJ1H6ud777odtZl5gG507'},
#       'href': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507',
#       'id': '5wJ1H6ud777odtZl5gG507',
#       'name': 'Vishal Mishra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wJ1H6ud777odtZl5gG507'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1N9rGbn2M9lzU6YcJ6081E'},
#     'href': 'https://api.spotify.com/v1/albums/1N9rGbn2M9lzU6YcJ6081E',
#     'id': '1N9rGbn2M9lzU6YcJ6081E',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dea88e870d30a4da51065bf5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dea88e870d30a4da51065bf5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dea88e870d30a4da51065bf5',
#       'width': 64}],
#     'name': 'Manjha',
#     'release_date': '2020-03-17',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1N9rGbn2M9lzU6YcJ6081E'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wJ1H6ud777odtZl5gG507'},
#      'href': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507',
#      'id': '5wJ1H6ud777odtZl5gG507',
#      'name': 'Vishal Mishra',
#      'type': 'artist',
#      'uri': 'spotify:artist:5wJ1H6ud777odtZl5gG507'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 191647,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR10S2097241'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0UZLaEOSIc5kg0cc7eszqC'},
#    'href': 'https://api.spotify.com/v1/tracks/0UZLaEOSIc5kg0cc7eszqC',
#    'id': '0UZLaEOSIc5kg0cc7eszqC',
#    'is_local': False,
#    'name': 'Manjha',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e1b06646485515bf929c036355c6d42f61f5c380?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0UZLaEOSIc5kg0cc7eszqC'},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6BHlJhCk1vjCG6hqTG2SFV'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Kahani Suno 2.0'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2022-05-31'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6BHlJhCk1vjCG6hqTG2SFV',
#   'name': 'Kahani Suno 2.0',
#   'release_date': '2022-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'},
#  {'album_id': '7kXEDaT5yy8IUT7Fmqs1i2',
#   'name': 'O Bedardeya (From "Tu Jhoothi Main Makkaar")',
#   'release_date': '2023-03-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7kXEDaT5yy8IUT7Fmqs1i2'},
#  {'album_id': '15CyNDuGY5fsG0Hn9rjnpG',
#   'name': 'Champagne Talk',
#   'release_date': '2022-10-12',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/15CyNDuGY5fsG0Hn9rjnpG'},
#  {'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'name': 'Brahmastra (Original Motion Picture Soundtrack)',
#   'release_date': '2022-10-06',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'},
#  {'album_id': '7khRLZe8P6XcUoRgOa3nnf',
#   'name': 'Malang Sajna',
#   'release_date': '2022-12-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7khRLZe8P6XcUoRgOa3nnf'},
#  {'album_id': '5uAi4ZZc7zRdd6PsKNcJXO',
#   'name': 'Tere Pyaar Mein (From "Tu Jhoothi Main Makkaar")',
#   'release_date': '2023-02-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5uAi4ZZc7zRdd6PsKNcJXO'},
#  {'album_id': '1zLlgNA1tyiabDhDwWhyPG',
#   'name': 'Kali Kali Zulfon Ke (Lo-Fi)',
#   'release_date': '2023-03-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1zLlgNA1tyiabDhDwWhyPG'},
#  {'album_id': '2ooWY7xriwwyj23dAI32C2',
#   'name': 'Pathaan',
#   'release_date': '2022-12-22',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2ooWY7xriwwyj23dAI32C2'},
#  {'album_id': '7uftfPn8f7lwtRLUrEVRYM',
#   'name': 'The Carnival',
#   'release_date': '2020-09-21',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/7uftfPn8f7lwtRLUrEVRYM'},
#  {'album_id': '3RaIXDlIRvziryGLXm8lBR',
#   'name': 'Daku',
#   'release_date': '2021-01-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3RaIXDlIRvziryGLXm8lBR'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '44aCFqUbG06fL58kqpMp8p',
#   'name': 'Baller',
#   'release_date': '2022-09-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/44aCFqUbG06fL58kqpMp8p'},
#  {'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'name': 'Love Forever With Arijit Singh',
#   'release_date': '2017-06-07',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/5Wm1nhxZqx7i0Hp6ZBqe9T'},
#  {'album_id': '5CvI5ppsG522pV554VLezD',
#   'name': 'Besharam Rang (From "Pathaan")',
#   'release_date': '2022-12-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5CvI5ppsG522pV554VLezD'},
#  {'album_id': '5Zcgog7sQ79ISF32y9nABU',
#   'name': 'No Love',
#   'release_date': '2022-02-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5Zcgog7sQ79ISF32y9nABU'},
#  {'album_id': '0azGrKHPYvl2MEKwQFfbV2',
#   'name': 'Mi Amor',
#   'release_date': '2022-09-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0azGrKHPYvl2MEKwQFfbV2'},
#  {'album_id': '1cttjZoENYipDCPgISthpY',
#   'name': 'Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Main Makkaar")',
#   'release_date': '2023-02-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1cttjZoENYipDCPgISthpY'},
#  {'album_id': '2b2GHWESCWEuHiCZ2Skedp',
#   'name': 'Calm Down (with Selena Gomez)',
#   'release_date': '2022-08-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2b2GHWESCWEuHiCZ2Skedp'},
#  {'album_id': '1lZk7TnMgvS3mSlfeWW1b3',
#   'name': 'Tere Hawaale (From "Laal Singh Chaddha")',
#   'release_date': '2022-08-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1lZk7TnMgvS3mSlfeWW1b3'},
#  {'album_id': '6FgtuX3PtiB5civjHYhc52',
#   'name': 'Safe Haven',
#   'release_date': '2017-05-05',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6FgtuX3PtiB5civjHYhc52'},
#  {'album_id': '4qlI6YM61j9NeGe832mExq',
#   'name': 'Forever',
#   'release_date': '2022-11-16',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/4qlI6YM61j9NeGe832mExq'},
#  {'album_id': '0Z1zYMwJRpvq0d9rdqTOYo',
#   'name': 'Ranjha (From "Shershaah")',
#   'release_date': '2021-08-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0Z1zYMwJRpvq0d9rdqTOYo'},
#  {'album_id': '2DKSZvMj7Da6rzNVPMgREj',
#   'name': 'Raataan Lambiyan (From "Shershaah")',
#   'release_date': '2021-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2DKSZvMj7Da6rzNVPMgREj'},
#  {'album_id': '4gCNyS7pidfK3rKWhB3JOY',
#   'name': 'FOUR (Deluxe)',
#   'release_date': '2014-11-17',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/4gCNyS7pidfK3rKWhB3JOY'},
#  {'album_id': '2GPHbR6aZ2rZooX6dF1nwB',
#   'name': 'VIBIN',
#   'release_date': '2023-01-09',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2GPHbR6aZ2rZooX6dF1nwB'},
#  {'album_id': '6yiXkzHvC0OTmhfDQOEWtS',
#   'name': 'Mercury - Acts 1 & 2',
#   'release_date': '2022-07-01',
#   'total_tracks': 32,
#   'url': 'https://open.spotify.com/album/6yiXkzHvC0OTmhfDQOEWtS'},
#  {'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
#   'name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'release_date': '2019-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3I8PdIhk6pNm8Kv0HiF14V'},
#  {'album_id': '6AJaDEafyyyWWXHZQtcFGe',
#   'name': 'Chaand Baaliyan',
#   'release_date': '2020-03-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6AJaDEafyyyWWXHZQtcFGe'},
#  {'album_id': '65vqiJwNrkv0it9fclatIK',
#   'name': 'P.O.V (Point of View)',
#   'release_date': '2023-04-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/65vqiJwNrkv0it9fclatIK'},
#  {'album_id': '30CfQvXOWrJx6kCglMcbo3',
#   'name': 'Manike (From "Thank God")',
#   'release_date': '2022-09-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/30CfQvXOWrJx6kCglMcbo3'},
#  {'album_id': '6u5RdRVp5HBStyPRWvHcgm',
#   'name': 'Thaa',
#   'release_date': '2023-03-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6u5RdRVp5HBStyPRWvHcgm'},
#  {'album_id': '1ncyKqyZae6DoyjYaV9LmS',
#   'name': 'Kaise Hua (From "Kabir Singh")',
#   'release_date': '2019-06-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1ncyKqyZae6DoyjYaV9LmS'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '6IXfWhC7omotM4lt0ROmEr',
#   'name': 'Love Aaj Kal (Original Motion Picture Soundtrack)',
#   'release_date': '2020-02-14',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6IXfWhC7omotM4lt0ROmEr'},
#  {'album_id': '7o9sqNRikTO3eeira2Qlx2',
#   'name': '3:00 AM Sessions',
#   'release_date': '2023-02-07',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/7o9sqNRikTO3eeira2Qlx2'},
#  {'album_id': '7ARtQpvnPN2ucbmVHngLOs',
#   'name': 'Until I Found You (Em Beihold Version)',
#   'release_date': '2022-04-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7ARtQpvnPN2ucbmVHngLOs'},
#  {'album_id': '57EdVAPDFT7sRrndFBRzUf',
#   'name': 'Mann Mera',
#   'release_date': '2012-12-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/57EdVAPDFT7sRrndFBRzUf'},
#  {'album_id': '3GkXRRRkV3rfgwG1wJset9',
#   'name': 'Excuses',
#   'release_date': '2020-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3GkXRRRkV3rfgwG1wJset9'},
#  {'album_id': '4ysOhipyMXKstywus51VXS',
#   'name': 'Baarishein',
#   'release_date': '2018-01-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ysOhipyMXKstywus51VXS'},
#  {'album_id': '3Gv6LmSvfxkUFmw8KCmUEr',
#   'name': 'Rang Lageya',
#   'release_date': '2021-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Gv6LmSvfxkUFmw8KCmUEr'},
#  {'album_id': '4OYdTHNgjhXzgVjbqsb0tO',
#   'name': 'Jab We Met',
#   'release_date': '2007-09-21',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/4OYdTHNgjhXzgVjbqsb0tO'},
#  {'album_id': '5Hmh6N8oisrcuZKa8EY5dn',
#   'name': 'People',
#   'release_date': '2022-12-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5Hmh6N8oisrcuZKa8EY5dn'},
#  {'album_id': '3okhA6w5uau6ZNhnVpwVww',
#   'name': 'Indigo (Extended)',
#   'release_date': '2019-10-04',
#   'total_tracks': 42,
#   'url': 'https://open.spotify.com/album/3okhA6w5uau6ZNhnVpwVww'},
#  {'album_id': '4kIPlpwEZBK9JaI9pZHe79',
#   'name': 'Brahmastra (Original Motion Picture Soundtrack)',
#   'release_date': '2022-10-06',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4kIPlpwEZBK9JaI9pZHe79'},
#  {'album_id': '7pFrr9ypVrxpZNF97YUQjK',
#   'name': 'Asal Mein',
#   'release_date': '2020-02-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7pFrr9ypVrxpZNF97YUQjK'},
#  {'album_id': '45ZIondgVoMB84MQQaUo9T',
#   'name': 'Moosetape',
#   'release_date': '2021-05-15',
#   'total_tracks': 32,
#   'url': 'https://open.spotify.com/album/45ZIondgVoMB84MQQaUo9T'},
#  {'album_id': '2HZl13JCi3PIaqVlIkp4q6',
#   'name': 'Shor in the City (Original Motion Picture Soundtrack)',
#   'release_date': '2011-03-28',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/2HZl13JCi3PIaqVlIkp4q6'},
#  {'album_id': '77jAfTh3KH9K2reMOmTgOh',
#   'name': 'This Is Acting',
#   'release_date': '2016-01-29',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/77jAfTh3KH9K2reMOmTgOh'},
#  {'album_id': '5hzAIEMlQpsEGIQFvnFOQx',
#   'name': 'Duniyaa (From "Luka Chuppi")',
#   'release_date': '2019-02-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5hzAIEMlQpsEGIQFvnFOQx'},
#  {'album_id': '1N9rGbn2M9lzU6YcJ6081E',
#   'name': 'Manjha',
#   'release_date': '2020-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1N9rGbn2M9lzU6YcJ6081E'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2023-04-28T13:10:49Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1n9EM0Y4A89vuRiA93gSS9'},
#      'href': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9',
#      'id': '1n9EM0Y4A89vuRiA93gSS9',
#      'name': 'Kaifi Khalil',
#      'type': 'artist',
#      'uri': 'spotify:artist:1n9EM0Y4A89vuRiA93gSS9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6BHlJhCk1vjCG6hqTG2SFV'},
#    'href': 'https://api.spotify.com/v1/albums/6BHlJhCk1vjCG6hqTG2SFV',
#    'id': '6BHlJhCk1vjCG6hqTG2SFV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734697d4ee22b3f63c17a3b9ec',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024697d4ee22b3f63c17a3b9ec',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514697d4ee22b3f63c17a3b9ec',
#      'width': 64}],
#    'name': 'Kahani Suno 2.0',
#    'release_date': '2022-05-31',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6BHlJhCk1vjCG6hqTG2SFV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1n9EM0Y4A89vuRiA93gSS9'},
#     'href': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9',
#     'id': '1n9EM0Y4A89vuRiA93gSS9',
#     'name': 'Kaifi Khalil',
#     'type': 'artist',
#     'uri': 'spotify:artist:1n9EM0Y4A89vuRiA93gSS9'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 173637,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'QZK6Q2278612'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4VsP4Dm8gsibRxB5I2hEkw'},
#   'href': 'https://api.spotify.com/v1/tracks/4VsP4Dm8gsibRxB5I2hEkw',
#   'id': '4VsP4Dm8gsibRxB5I2hEkw',
#   'is_local': False,
#   'name': 'Kahani Suno 2.0',
#   'popularity': 85,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2c644e9345d1a0ab97e4541d26b6b8ccb2c889f9?cid=128ec03e1b5c49e78ef1bd71cd30e25d',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4VsP4Dm8gsibRxB5I2hEkw'},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1n9EM0Y4A89vuRiA93gSS9',
#   'artist_name': 'Kaifi Khalil',
#   'external_url': 'https://api.spotify.com/v1/artists/1n9EM0Y4A89vuRiA93gSS9'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artist_name': 'Sachet Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artist_id': '1E6arsXf5Fgsnv9YpSzjpE',
#   'artist_name': 'Parampara Tandon',
#   'external_url': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '3tPQOjkxO3mrYrrgkTeXgH',
#   'artist_name': 'Nikhita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH'},
#  {'artist_id': '2kfi47LWmlXzQ3p3kWonfQ',
#   'artist_name': 'Madhur Sharma',
#   'external_url': 'https://api.spotify.com/v1/artists/2kfi47LWmlXzQ3p3kWonfQ'},
#  {'artist_id': '16023OFrIxSmKOMpIVJ6Ax',
#   'artist_name': 'Swapnil Tare',
#   'external_url': 'https://api.spotify.com/v1/artists/16023OFrIxSmKOMpIVJ6Ax'},
#  {'artist_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artist_name': 'Nusrat Fateh Ali Khan',
#   'external_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb',
#   'artist_name': 'Vishal-Shekhar',
#   'external_url': 'https://api.spotify.com/v1/artists/6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '3FgHkfb3IqG4WKuVe1xCXM',
#   'artist_name': 'Sukriti Kakar',
#   'external_url': 'https://api.spotify.com/v1/artists/3FgHkfb3IqG4WKuVe1xCXM'},
#  {'artist_id': '6CXEwIaXYfVJ84biCxqc9k',
#   'artist_name': 'Vishal Dadlani',
#   'external_url': 'https://api.spotify.com/v1/artists/6CXEwIaXYfVJ84biCxqc9k'},
#  {'artist_id': '4xd7mLI7urqrxELaXhAvzw',
#   'artist_name': 'Shekhar Ravjiani',
#   'external_url': 'https://api.spotify.com/v1/artists/4xd7mLI7urqrxELaXhAvzw'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '5NHm4TU5Twz7owibYxJfFU',
#   'artist_name': 'King',
#   'external_url': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU'},
#  {'artist_id': '1sSYaQBOI71QZDZ9OWW3hp',
#   'artist_name': 'Chani Nattan',
#   'external_url': 'https://api.spotify.com/v1/artists/1sSYaQBOI71QZDZ9OWW3hp'},
#  {'artist_id': '4Lk9Mory8nRTolPO1TMMcN',
#   'artist_name': 'Inderpal Moga',
#   'external_url': 'https://api.spotify.com/v1/artists/4Lk9Mory8nRTolPO1TMMcN'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '3nqS8jzqmsPKFJTp0BOIel',
#   'artist_name': 'Ikky',
#   'external_url': 'https://api.spotify.com/v1/artists/3nqS8jzqmsPKFJTp0BOIel'},
#  {'artist_id': '3gBKY0y3dFFVRqicLnVZYz',
#   'artist_name': 'Alka Yagnik',
#   'external_url': 'https://api.spotify.com/v1/artists/3gBKY0y3dFFVRqicLnVZYz'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb',
#   'artist_name': 'Vishal-Shekhar',
#   'external_url': 'https://api.spotify.com/v1/artists/6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '2Yf4MRVpt0rcAd5y5h5ph1',
#   'artist_name': 'Caralisa Monteiro',
#   'external_url': 'https://api.spotify.com/v1/artists/2Yf4MRVpt0rcAd5y5h5ph1'},
#  {'artist_id': '6CXEwIaXYfVJ84biCxqc9k',
#   'artist_name': 'Vishal Dadlani',
#   'external_url': 'https://api.spotify.com/v1/artists/6CXEwIaXYfVJ84biCxqc9k'},
#  {'artist_id': '4xd7mLI7urqrxELaXhAvzw',
#   'artist_name': 'Shekhar Ravjiani',
#   'external_url': 'https://api.spotify.com/v1/artists/4xd7mLI7urqrxELaXhAvzw'},
#  {'artist_id': '0m3D4grap8VFSzbJMqgNVk',
#   'artist_name': 'Kumaar',
#   'external_url': 'https://api.spotify.com/v1/artists/0m3D4grap8VFSzbJMqgNVk'},
#  {'artist_id': '5r3wPya2PpeTTsXsGhQU8O',
#   'artist_name': 'Shubh',
#   'external_url': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O'},
#  {'artist_id': '74RGMjbSsFv5RLj8wVx9Yv',
#   'artist_name': 'Sharn',
#   'external_url': 'https://api.spotify.com/v1/artists/74RGMjbSsFv5RLj8wVx9Yv'},
#  {'artist_id': '6nAMu7pGqdwUSsGMZPUvSk',
#   'artist_name': '40k',
#   'external_url': 'https://api.spotify.com/v1/artists/6nAMu7pGqdwUSsGMZPUvSk'},
#  {'artist_id': '1i31OYo0s5VoMCaMRJFZkJ',
#   'artist_name': 'The Paul',
#   'external_url': 'https://api.spotify.com/v1/artists/1i31OYo0s5VoMCaMRJFZkJ'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '3hbwOFtgWSNfeRzF2o7Y65',
#   'artist_name': 'Charan',
#   'external_url': 'https://api.spotify.com/v1/artists/3hbwOFtgWSNfeRzF2o7Y65'},
#  {'artist_id': '46pWGuE3dSwY3bMMXGBvVS',
#   'artist_name': 'Rema',
#   'external_url': 'https://api.spotify.com/v1/artists/46pWGuE3dSwY3bMMXGBvVS'},
#  {'artist_id': '0C8ZW7ezQVs4URX5aX7Kqx',
#   'artist_name': 'Selena Gomez',
#   'external_url': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '2WzaAvm2bBCf4pEhyuDgCY',
#   'artist_name': 'Ruth B.',
#   'external_url': 'https://api.spotify.com/v1/artists/2WzaAvm2bBCf4pEhyuDgCY'},
#  {'artist_id': '3lmszXxkp47K9kDCRRPU8p',
#   'artist_name': 'Laddi Chahal',
#   'external_url': 'https://api.spotify.com/v1/artists/3lmszXxkp47K9kDCRRPU8p'},
#  {'artist_id': '3OQRPFFS3OsltFjFAXu1kE',
#   'artist_name': 'Parmish Verma',
#   'external_url': 'https://api.spotify.com/v1/artists/3OQRPFFS3OsltFjFAXu1kE'},
#  {'artist_id': '55kkrbuMkdzPGD7YGA6xrJ',
#   'artist_name': 'Gurlez Akhtar',
#   'external_url': 'https://api.spotify.com/v1/artists/55kkrbuMkdzPGD7YGA6xrJ'},
#  {'artist_id': '74OaRjmyh0XyRZsQQQ5l7c',
#   'artist_name': 'Jasleen Royal',
#   'external_url': 'https://api.spotify.com/v1/artists/74OaRjmyh0XyRZsQQQ5l7c'},
#  {'artist_id': '56SjZARoEvag3RoKWIb16j',
#   'artist_name': 'B Praak',
#   'external_url': 'https://api.spotify.com/v1/artists/56SjZARoEvag3RoKWIb16j'},
#  {'artist_id': '0bRPtPZQkWHeG7MGk9eWlh',
#   'artist_name': 'Romy',
#   'external_url': 'https://api.spotify.com/v1/artists/0bRPtPZQkWHeG7MGk9eWlh'},
#  {'artist_id': '4nJ0kto93jDLHQKmpGeYS8',
#   'artist_name': 'Anvita Dutt',
#   'external_url': 'https://api.spotify.com/v1/artists/4nJ0kto93jDLHQKmpGeYS8'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '1sVmXkzX2ukc6QvasrDBES',
#   'artist_name': 'Asees Kaur',
#   'external_url': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES'},
#  {'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'external_url': 'https://api.spotify.com/v1/artists/4AK6F7OLvEQ5QYCBNiQWHq'},
#  {'artist_id': '2vJvM1hPBYqDoGBje0kRMd',
#   'artist_name': 'Jassa Dhillon',
#   'external_url': 'https://api.spotify.com/v1/artists/2vJvM1hPBYqDoGBje0kRMd'},
#  {'artist_id': '54BjV0qctcWp8xOip7uaJD',
#   'artist_name': 'thiarajxtt',
#   'external_url': 'https://api.spotify.com/v1/artists/54BjV0qctcWp8xOip7uaJD'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artist_name': 'Mithoon',
#   'external_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artist_id': '4wwYGgSpeBtvk5WX6HBqzw',
#   'artist_name': 'Aditya A',
#   'external_url': 'https://api.spotify.com/v1/artists/4wwYGgSpeBtvk5WX6HBqzw'},
#  {'artist_id': '6DARBhWbfcS9E4yJzcliqQ',
#   'artist_name': 'Karan Aujla',
#   'external_url': 'https://api.spotify.com/v1/artists/6DARBhWbfcS9E4yJzcliqQ'},
#  {'artist_id': '3GOxylxqB046EtIQynePq2',
#   'artist_name': 'Yeah Proof',
#   'external_url': 'https://api.spotify.com/v1/artists/3GOxylxqB046EtIQynePq2'},
#  {'artist_id': '6hyCmqlpgEhkMKKr65sFgI',
#   'artist_name': 'Yohani',
#   'external_url': 'https://api.spotify.com/v1/artists/6hyCmqlpgEhkMKKr65sFgI'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '5r2baeTwcCJnuIsDIlxUJo',
#   'artist_name': 'Rashmi Virag',
#   'external_url': 'https://api.spotify.com/v1/artists/5r2baeTwcCJnuIsDIlxUJo'},
#  {'artist_id': '0GiAC4VvvYCypjRH6IiasK',
#   'artist_name': 'Surya Ragunaathan',
#   'external_url': 'https://api.spotify.com/v1/artists/0GiAC4VvvYCypjRH6IiasK'},
#  {'artist_id': '4C19flKmMm12gRxmBJWMCV',
#   'artist_name': 'Varinder Brar',
#   'external_url': 'https://api.spotify.com/v1/artists/4C19flKmMm12gRxmBJWMCV'},
#  {'artist_id': '3quojFCZjKk1j5zIv0HX2P',
#   'artist_name': 'Rav Dhaliwal',
#   'external_url': 'https://api.spotify.com/v1/artists/3quojFCZjKk1j5zIv0HX2P'},
#  {'artist_id': '2YzXsQoI3rqYNEVd4nac7g',
#   'artist_name': 'Ultra Beats',
#   'external_url': 'https://api.spotify.com/v1/artists/2YzXsQoI3rqYNEVd4nac7g'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '0y59o4v8uw5crbN9M3JiL1',
#   'artist_name': 'Badshah',
#   'external_url': 'https://api.spotify.com/v1/artists/0y59o4v8uw5crbN9M3JiL1'},
#  {'artist_id': '6DARBhWbfcS9E4yJzcliqQ',
#   'artist_name': 'Karan Aujla',
#   'external_url': 'https://api.spotify.com/v1/artists/6DARBhWbfcS9E4yJzcliqQ'},
#  {'artist_id': '0V8aeNb0fnR2P8eZVrx3lI',
#   'artist_name': 'Devika Badyal',
#   'external_url': 'https://api.spotify.com/v1/artists/0V8aeNb0fnR2P8eZVrx3lI'},
#  {'artist_id': '5XKFrudbV4IiuE5WuTPRmT',
#   'artist_name': 'Stephen Sanchez',
#   'external_url': 'https://api.spotify.com/v1/artists/5XKFrudbV4IiuE5WuTPRmT'},
#  {'artist_id': '7o2ZQYM7nTsaVdkXY38UAA',
#   'artist_name': 'Em Beihold',
#   'external_url': 'https://api.spotify.com/v1/artists/7o2ZQYM7nTsaVdkXY38UAA'},
#  {'artist_id': '4fdvt615NKbd5n2s1cLiQZ',
#   'artist_name': 'ronixd',
#   'external_url': 'https://api.spotify.com/v1/artists/4fdvt615NKbd5n2s1cLiQZ'},
#  {'artist_id': '6LEG9Ld1aLImEFEVHdWNSB',
#   'artist_name': 'AP Dhillon',
#   'external_url': 'https://api.spotify.com/v1/artists/6LEG9Ld1aLImEFEVHdWNSB'},
#  {'artist_id': '5DHi2MeoRgAwPE0A0qwRMl',
#   'artist_name': 'Gurinder Gill',
#   'external_url': 'https://api.spotify.com/v1/artists/5DHi2MeoRgAwPE0A0qwRMl'},
#  {'artist_id': '0OS0NZnK7TGIAWx8MkWNFN',
#   'artist_name': 'Intense',
#   'external_url': 'https://api.spotify.com/v1/artists/0OS0NZnK7TGIAWx8MkWNFN'},
#  {'artist_id': '4gdMJYnopf2nEUcanAwstx',
#   'artist_name': 'Anuv Jain',
#   'external_url': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx'},
#  {'artist_id': '5GnnSrwNCGyfAU4zuIytiS',
#   'artist_name': 'Mohit Chauhan',
#   'external_url': 'https://api.spotify.com/v1/artists/5GnnSrwNCGyfAU4zuIytiS'},
#  {'artist_id': '3dN9MQpjIyNxyeRfz4EDZe',
#   'artist_name': 'Rochak Kohli',
#   'external_url': 'https://api.spotify.com/v1/artists/3dN9MQpjIyNxyeRfz4EDZe'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '5GnnSrwNCGyfAU4zuIytiS',
#   'artist_name': 'Mohit Chauhan',
#   'external_url': 'https://api.spotify.com/v1/artists/5GnnSrwNCGyfAU4zuIytiS'},
#  {'artist_id': '7kjSuFGKhLm8b5qXoMhRkJ',
#   'artist_name': 'Libianca',
#   'external_url': 'https://api.spotify.com/v1/artists/7kjSuFGKhLm8b5qXoMhRkJ'},
#  {'artist_id': '7bXgB6jMjp9ATFy66eO08Z',
#   'artist_name': 'Chris Brown',
#   'external_url': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'external_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '00sCATpEvwH48ays7PlQFU',
#   'artist_name': 'Jonita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/00sCATpEvwH48ays7PlQFU'},
#  {'artist_id': '2GoeZ0qOTt6kjsWW4eA6LS',
#   'artist_name': 'Darshan Raval',
#   'external_url': 'https://api.spotify.com/v1/artists/2GoeZ0qOTt6kjsWW4eA6LS'},
#  {'artist_id': '4PULA4EFzYTrxYvOVlwpiQ',
#   'artist_name': 'Sidhu Moose Wala',
#   'external_url': 'https://api.spotify.com/v1/artists/4PULA4EFzYTrxYvOVlwpiQ'},
#  {'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'external_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '6k6dimE4a6OFnD0HWmkIUW',
#   'artist_name': 'Tochi Raina',
#   'external_url': 'https://api.spotify.com/v1/artists/6k6dimE4a6OFnD0HWmkIUW'},
#  {'artist_id': '5WUlDfRSoLAfcVSX1WnrxN',
#   'artist_name': 'Sia',
#   'external_url': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN'},
#  {'artist_id': '6zZrFenNe3YPttxZsnQQs1',
#   'artist_name': 'Akhil',
#   'external_url': 'https://api.spotify.com/v1/artists/6zZrFenNe3YPttxZsnQQs1'},
#  {'artist_id': '1OPqAyxsQc8mcRmoNBAnVk',
#   'artist_name': 'Dhvani Bhanushali',
#   'external_url': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk'},
#  {'artist_id': '52XgeWw24o4klNdfwvB0Vx',
#   'artist_name': 'Kunaal Vermaa',
#   'external_url': 'https://api.spotify.com/v1/artists/52XgeWw24o4klNdfwvB0Vx'},
#  {'artist_id': '5wJ1H6ud777odtZl5gG507',
#   'artist_name': 'Vishal Mishra',
#   'external_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head(10)
# Out:
#                  album_id                                              name  \
# 0  6BHlJhCk1vjCG6hqTG2SFV                                   Kahani Suno 2.0
# 1  7kXEDaT5yy8IUT7Fmqs1i2      O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 2  15CyNDuGY5fsG0Hn9rjnpG                                    Champagne Talk
# 3  4kIPlpwEZBK9JaI9pZHe79   Brahmastra (Original Motion Picture Soundtrack)
# 4  7khRLZe8P6XcUoRgOa3nnf                                      Malang Sajna
# 5  5uAi4ZZc7zRdd6PsKNcJXO  Tere Pyaar Mein (From "Tu Jhoothi Main Makkaar")
# 6  1zLlgNA1tyiabDhDwWhyPG                       Kali Kali Zulfon Ke (Lo-Fi)
# 7  2ooWY7xriwwyj23dAI32C2                                           Pathaan
# 8  7uftfPn8f7lwtRLUrEVRYM                                      The Carnival
# 9  3RaIXDlIRvziryGLXm8lBR                                              Daku
#
#   release_date  total_tracks  \
# 0   2022-05-31             1
# 1   2023-03-04             1
# 2   2022-10-12             8
# 3   2022-10-06             9
# 4   2022-12-19             1
# 5   2023-02-01             1
# 6   2023-03-31             1
# 7   2022-12-22             4
# 8   2020-09-21             8
# 9   2021-01-16             1
#
#                                                  url
# 0  https://open.spotify.com/album/6BHlJhCk1vjCG6h...
# 1  https://open.spotify.com/album/7kXEDaT5yy8IUT7...
# 2  https://open.spotify.com/album/15CyNDuGY5fsG0H...
# 3  https://open.spotify.com/album/4kIPlpwEZBK9JaI...
# 4  https://open.spotify.com/album/7khRLZe8P6XcUoR...
# 5  https://open.spotify.com/album/5uAi4ZZc7zRdd6P...
# 6  https://open.spotify.com/album/1zLlgNA1tyiabDh...
# 7  https://open.spotify.com/album/2ooWY7xriwwyj23...
# 8  https://open.spotify.com/album/7uftfPn8f7lwtRL...
# 9  https://open.spotify.com/album/3RaIXDlIRvziryG...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  4VsP4Dm8gsibRxB5I2hEkw                               Kahani Suno 2.0
# 1  0czcoKJbJt08NqKrvSbbz7  O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 2  1418IuVKQPTYqt7QNJ9RXN                                Maan Meri Jaan
# 3  4UMIv5jd9gK98a39BQRD9X                                      Kesariya
# 4  73K33p4Vyz9koXGqmL5eFs                                  Malang Sajna
#
#    duration_ms                                                url  popularity  \
# 0       173637  https://open.spotify.com/track/4VsP4Dm8gsibRxB...          85
# 1       313051  https://open.spotify.com/track/0czcoKJbJt08NqK...          82
# 2       194653  https://open.spotify.com/track/1418IuVKQPTYqt7...          86
# 3       268164  https://open.spotify.com/track/4UMIv5jd9gK98a3...          77
# 4       161041  https://open.spotify.com/track/73K33p4Vyz9koXG...          82
#
#              song_added                album_id               artist_id
# 0  2023-04-28T13:10:49Z  6BHlJhCk1vjCG6hqTG2SFV  1n9EM0Y4A89vuRiA93gSS9
# 1  2023-04-28T13:10:49Z  7kXEDaT5yy8IUT7Fmqs1i2  1wRPtKGflJrBx9BmLsSwlU
# 2  2023-04-28T13:10:49Z  15CyNDuGY5fsG0Hn9rjnpG  5NHm4TU5Twz7owibYxJfFU
# 3  2023-04-28T13:10:49Z  4kIPlpwEZBK9JaI9pZHe79  1wRPtKGflJrBx9BmLsSwlU
# 4  2023-04-28T13:10:49Z  7khRLZe8P6XcUoRgOa3nnf  6WOdPJmexxFINcKMkP2jMG

# %%
artist_df.head()
# Out:
#                 artist_id           artist_name  \
# 0  1n9EM0Y4A89vuRiA93gSS9          Kaifi Khalil
# 1  1wRPtKGflJrBx9BmLsSwlU                Pritam
# 2  4YRxDV8wJFPHPTeXepOstw          Arijit Singh
# 3  2fMqTqiTxUDlmcOEPaQSsx  Amitabh Bhattacharya
# 4  5NHm4TU5Twz7owibYxJfFU                  King
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1n9EM0Y4A89...
# 1  https://api.spotify.com/v1/artists/1wRPtKGflJr...
# 2  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 3  https://api.spotify.com/v1/artists/2fMqTqiTxUD...
# 4  https://api.spotify.com/v1/artists/5NHm4TU5Twz...

# %%
album_df.head()
# Out:
#                  album_id                                             name  \
# 0  6BHlJhCk1vjCG6hqTG2SFV                                  Kahani Suno 2.0
# 1  7kXEDaT5yy8IUT7Fmqs1i2     O Bedardeya (From "Tu Jhoothi Main Makkaar")
# 2  15CyNDuGY5fsG0Hn9rjnpG                                   Champagne Talk
# 3  4kIPlpwEZBK9JaI9pZHe79  Brahmastra (Original Motion Picture Soundtrack)
# 4  7khRLZe8P6XcUoRgOa3nnf                                     Malang Sajna
#
#   release_date  total_tracks  \
# 0   2022-05-31             1
# 1   2023-03-04             1
# 2   2022-10-12             8
# 3   2022-10-06             9
# 4   2022-12-19             1
#
#                                                  url
# 0  https://open.spotify.com/album/6BHlJhCk1vjCG6h...
# 1  https://open.spotify.com/album/7kXEDaT5yy8IUT7...
# 2  https://open.spotify.com/album/15CyNDuGY5fsG0H...
# 3  https://open.spotify.com/album/4kIPlpwEZBK9JaI...
# 4  https://open.spotify.com/album/7khRLZe8P6XcUoR...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
